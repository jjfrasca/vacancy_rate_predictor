# %% [markdown]
# ## Data Wrangling Home Prices by Zipcode
# from Zillow public data

# %%
#Import pandas, matplotlib.pyplot, and seaborn
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np

# %%
#change directory to get data
path= '/Users/josephfrasca/Coding_Stuff/Springboard/Capstone_2/data/raw'
os.chdir(path)

# %%
os.listdir()
# Out:
# ['.DS_Store',
#  '.gitkeep',
#  '.ipynb_checkpoints',
#  'ACS_RentPrice_byZipcodes_productDownload_2020-10-22T230534',
#  'fredgraph',
#  'HousingUnits_byZipcode_ACS',
#  'med_rent?.csv',
#  'med_rent??.csv',
#  'Median_Income_byZipcode_ACS',
#  'Median_Rent_AND_HomePrice_byZipcode_ACS',
#  'NationalfredgraphForZipcodes.csv',
#  'Population_byZipcode_ACS',
#  'Unemployment_byZipcode_ACS',
#  'Vacancy_Rate_Natnl_2011-2019.csv',
#  'VacanyRateData-ByZipcode',
#  'Zip_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_mon.csv',
#  'Zip_ZORI_AllHomesPlusMultifamily_SSA.csv']

# %% [markdown]
# ### Data Loading

# %%
#load home price data
df_homes = pd.read_csv('Zip_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_mon.csv')

# %%
df_homes
# Out:
#        RegionID  SizeRank  RegionName RegionType StateName State       City  \
# 0         61639         0       10025        Zip        NY    NY   New York
# 1         84654         1       60657        Zip        IL    IL    Chicago
# 2         61637         2       10023        Zip        NY    NY   New York
# 3         91982         3       77494        Zip        TX    TX       Katy
# 4         84616         4       60614        Zip        IL    IL    Chicago
# ...         ...       ...         ...        ...       ...   ...        ...
# 30362     76721     34430       43523        Zip        OH    OH    Malinta
# 30363     60758     34430        7703        Zip        NJ    NJ  Eatontown
# 30364     78801     34430       47865        Zip        IN    IN   Carlisle
# 30365     58117     35187         822        Zip        LA    LA  Choudrant
# 30366     58115     35187         820        Zip        LA    LA  Choudrant
#
#                                   Metro       CountyName  1996-01-31  ...  \
# 0           New York-Newark-Jersey City  New York County    194499.0  ...
# 1              Chicago-Naperville-Elgin      Cook County    209719.0  ...
# 2           New York-Newark-Jersey City  New York County    220104.0  ...
# 3      Houston-The Woodlands-Sugar Land    Harris County    203697.0  ...
# 4              Chicago-Naperville-Elgin      Cook County    282776.0  ...
# ...                                 ...              ...         ...  ...
# 30362                               NaN     Henry County     59788.0  ...
# 30363       New York-Newark-Jersey City  Monmouth County         NaN  ...
# 30364                       Terre Haute  Sullivan County         NaN  ...
# 30365                            Ruston   Lincoln Parish         NaN  ...
# 30366                            Ruston   Lincoln Parish         NaN  ...
#
#        2019-12-31  2020-01-31  2020-02-29  2020-03-31  2020-04-30  2020-05-31  \
# 0       1017161.0   1001805.0    981628.0    956932.0    946262.0    938152.0
# 1        486137.0    485977.0    487138.0    488788.0    489947.0    490298.0
# 2       1047657.0   1065121.0   1076998.0   1077073.0   1085711.0   1090631.0
# 3        341746.0    341495.0    341715.0    342198.0    343290.0    344231.0
# 4        633132.0    632775.0    633032.0    633716.0    633404.0    633244.0
# ...           ...         ...         ...         ...         ...         ...
# 30362     84560.0     84810.0     84821.0     84700.0     84762.0     84444.0
# 30363    562614.0    565882.0    569174.0    572657.0    577028.0    580373.0
# 30364     43732.0     43849.0     43868.0     43780.0     43586.0     43286.0
# 30365    194690.0    194985.0    196153.0    196851.0    196933.0    195992.0
# 30366    243796.0    243294.0    243640.0    244174.0    244171.0    243361.0
#
#        2020-06-30  2020-07-31  2020-08-31  2020-09-30
# 0        935478.0    933945.0    934712.0    938408.0
# 1        490907.0    492421.0    494773.0    497988.0
# 2       1095708.0   1098853.0   1106245.0   1123239.0
# 3        344812.0    345089.0    345863.0    346555.0
# 4        633346.0    634618.0    636295.0    639390.0
# ...           ...         ...         ...         ...
# 30362     84278.0     84093.0     83923.0     83149.0
# 30363    583376.0    585594.0    589446.0    595863.0
# 30364     42857.0     42340.0     41629.0     40874.0
# 30365    195631.0    195314.0    195655.0    195484.0
# 30366    243784.0    242183.0    239440.0    234039.0
#
# [30367 rows x 306 columns]

# %% [markdown]
# ## Data Definition - Home Prices

# %%
df_homes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30367 entries, 0 to 30366
# Columns: 306 entries, RegionID to 2020-09-30
# dtypes: float64(297), int64(3), object(6)
# memory usage: 70.9+ MB

# %%
df_homes.isna().sum()/len(df_homes)*100
# Out:
# RegionID      0.0
# SizeRank      0.0
# RegionName    0.0
# RegionType    0.0
# StateName     0.0
#              ...
# 2020-05-31    0.0
# 2020-06-30    0.0
# 2020-07-31    0.0
# 2020-08-31    0.0
# 2020-09-30    0.0
# Length: 306, dtype: float64

# %%
df_homes.head()
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     61639         0       10025        Zip        NY    NY  New York
# 1     84654         1       60657        Zip        IL    IL   Chicago
# 2     61637         2       10023        Zip        NY    NY  New York
# 3     91982         3       77494        Zip        TX    TX      Katy
# 4     84616         4       60614        Zip        IL    IL   Chicago
#
#                               Metro       CountyName  1996-01-31  ...  \
# 0       New York-Newark-Jersey City  New York County    194499.0  ...
# 1          Chicago-Naperville-Elgin      Cook County    209719.0  ...
# 2       New York-Newark-Jersey City  New York County    220104.0  ...
# 3  Houston-The Woodlands-Sugar Land    Harris County    203697.0  ...
# 4          Chicago-Naperville-Elgin      Cook County    282776.0  ...
#
#    2019-12-31  2020-01-31  2020-02-29  2020-03-31  2020-04-30  2020-05-31  \
# 0   1017161.0   1001805.0    981628.0    956932.0    946262.0    938152.0
# 1    486137.0    485977.0    487138.0    488788.0    489947.0    490298.0
# 2   1047657.0   1065121.0   1076998.0   1077073.0   1085711.0   1090631.0
# 3    341746.0    341495.0    341715.0    342198.0    343290.0    344231.0
# 4    633132.0    632775.0    633032.0    633716.0    633404.0    633244.0
#
#    2020-06-30  2020-07-31  2020-08-31  2020-09-30
# 0    935478.0    933945.0    934712.0    938408.0
# 1    490907.0    492421.0    494773.0    497988.0
# 2   1095708.0   1098853.0   1106245.0   1123239.0
# 3    344812.0    345089.0    345863.0    346555.0
# 4    633346.0    634618.0    636295.0    639390.0
#
# [5 rows x 306 columns]

# %% [markdown]
# ### Data Cleaning - Home Prices

# %%
#isolate annual DataFrames from 2011-2020
df_homes_2011 = df_homes.iloc[:, np.r_[0:9,189:201]]
df_homes_2012 = df_homes.iloc[:, np.r_[0:9,201:213]]
df_homes_2013 = df_homes.iloc[:, np.r_[0:9,213:225]]
df_homes_2014 = df_homes.iloc[:, np.r_[0:9,225:237]]
df_homes_2015 = df_homes.iloc[:, np.r_[0:9,237:249]]
df_homes_2016 = df_homes.iloc[:, np.r_[0:9,249:261]]
df_homes_2017 = df_homes.iloc[:, np.r_[0:9,261:273]]
df_homes_2018 = df_homes.iloc[:, np.r_[0:9,273:285]]
df_homes_2019 = df_homes.iloc[:, np.r_[0:9,285:297]]
df_homes_2020 = df_homes.iloc[:, np.r_[0:9,297:306]]

# %%
df_homes_2020.head()
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     61639         0       10025        Zip        NY    NY  New York
# 1     84654         1       60657        Zip        IL    IL   Chicago
# 2     61637         2       10023        Zip        NY    NY  New York
# 3     91982         3       77494        Zip        TX    TX      Katy
# 4     84616         4       60614        Zip        IL    IL   Chicago
#
#                               Metro       CountyName  2020-01-31  2020-02-29  \
# 0       New York-Newark-Jersey City  New York County   1001805.0    981628.0
# 1          Chicago-Naperville-Elgin      Cook County    485977.0    487138.0
# 2       New York-Newark-Jersey City  New York County   1065121.0   1076998.0
# 3  Houston-The Woodlands-Sugar Land    Harris County    341495.0    341715.0
# 4          Chicago-Naperville-Elgin      Cook County    632775.0    633032.0
#
#    2020-03-31  2020-04-30  2020-05-31  2020-06-30  2020-07-31  2020-08-31  \
# 0    956932.0    946262.0    938152.0    935478.0    933945.0    934712.0
# 1    488788.0    489947.0    490298.0    490907.0    492421.0    494773.0
# 2   1077073.0   1085711.0   1090631.0   1095708.0   1098853.0   1106245.0
# 3    342198.0    343290.0    344231.0    344812.0    345089.0    345863.0
# 4    633716.0    633404.0    633244.0    633346.0    634618.0    636295.0
#
#    2020-09-30
# 0    938408.0
# 1    497988.0
# 2   1123239.0
# 3    346555.0
# 4    639390.0

# %%
#check NaNs
df_homes_2011.isna().sum()/len(df_homes_2011)*100
# Out:
# RegionID       0.000000
# SizeRank       0.000000
# RegionName     0.000000
# RegionType     0.000000
# StateName      0.000000
# State          0.000000
# City           0.000000
# Metro         23.439918
# CountyName     0.000000
# 2011-01-31    11.084401
# 2011-02-28    10.959265
# 2011-03-31    10.781440
# 2011-04-30    10.662891
# 2011-05-31    10.623374
# 2011-06-30    10.547634
# 2011-07-31    10.448842
# 2011-08-31    10.346758
# 2011-09-30    10.247967
# 2011-10-31    10.162347
# 2011-11-30    10.096486
# 2011-12-31    10.030625
# dtype: float64

# %%
#list of when Metro column = NaN
metro_nan = df_homes_2011[df_homes_2011['Metro'].isna() == True]
metro_nan.nunique()
# Out:
# RegionID      7118
# SizeRank      2600
# RegionName    7118
# RegionType       1
# StateName       45
# State           45
# City          5145
# Metro            0
# CountyName     796
# 2011-01-31    5392
# 2011-02-28    5393
# 2011-03-31    5445
# 2011-04-30    5433
# 2011-05-31    5460
# 2011-06-30    5455
# 2011-07-31    5463
# 2011-08-31    5498
# 2011-09-30    5511
# 2011-10-31    5511
# 2011-11-30    5528
# 2011-12-31    5520
# dtype: int64

# %%
metro_nan
# Out:
#        RegionID  SizeRank  RegionName RegionType StateName State  \
# 2716      70178      2742       28734        Zip        NC    NC
# 3035      91865      3066       77351        Zip        TX    TX
# 3822      75303      3865       39452        Zip        MS    MS
# 4293      74894      4344       38583        Zip        TN    TN
# 4297      71180      4348       30533        Zip        GA    GA
# ...         ...       ...         ...        ...       ...   ...
# 30349     72032     34430       32511        Zip        MO    MO
# 30352     91903     34430       77399        Zip        TX    TX
# 30356     58084     34430         742        Zip        CO    CO
# 30361     61693     34430       10117        Zip        OH    OH
# 30362     76721     34430       43523        Zip        OH    OH
#
#                   City Metro       CountyName  2011-01-31  ...  2011-03-31  \
# 2716          Franklin   NaN     Macon County    153793.0  ...    152528.0
# 3035   West Livingston   NaN      Polk County     94710.0  ...     95436.0
# 3822          Lucedale   NaN    George County    102934.0  ...    102245.0
# 4293            Sparta   NaN     White County     89243.0  ...     88609.0
# 4297         Dahlonega   NaN   Lumpkin County    141668.0  ...    139465.0
# ...                ...   ...              ...         ...  ...         ...
# 30349            Macon   NaN     Macon County         NaN  ...         NaN
# 30352         Corrigan   NaN      Polk County     66909.0  ...     67047.0
# 30356            Ceiba   NaN  Gunnison County    294530.0  ...    298415.0
# 30361          Piketon   NaN      Pike County         NaN  ...         NaN
# 30362          Malinta   NaN     Henry County     65176.0  ...     64561.0
#
#        2011-04-30  2011-05-31  2011-06-30  2011-07-31  2011-08-31  2011-09-30  \
# 2716     151777.0    151037.0    150402.0    149818.0    149429.0    149201.0
# 3035      95633.0     95172.0     94580.0     94137.0     94022.0     94023.0
# 3822     101849.0    101628.0    101491.0    101543.0    101676.0    101686.0
# 4293      88289.0     88112.0     88092.0     88100.0     88104.0     88154.0
# 4297     137939.0    136531.0    135736.0    135160.0    134607.0    134005.0
# ...           ...         ...         ...         ...         ...         ...
# 30349         NaN         NaN         NaN         NaN         NaN         NaN
# 30352     67081.0     66900.0     66796.0     66885.0     67108.0     66939.0
# 30356    298529.0    301292.0    299328.0    299799.0    297791.0    296561.0
# 30361         NaN         NaN         NaN         NaN         NaN         NaN
# 30362     64294.0     64163.0     64078.0     64115.0     64148.0     64160.0
#
#        2011-10-31  2011-11-30  2011-12-31
# 2716     148828.0    148115.0    147158.0
# 3035      93766.0     94038.0     94147.0
# 3822     101542.0    101630.0    101700.0
# 4293      88216.0     88241.0     88181.0
# 4297     133173.0    132698.0    132144.0
# ...           ...         ...         ...
# 30349         NaN         NaN         NaN
# 30352     66834.0     67367.0     68383.0
# 30356    298728.0    300339.0    301188.0
# 30361         NaN         NaN         NaN
# 30362     64134.0     63969.0     64040.0
#
# [7118 rows x 21 columns]

# %%
#create new column for aver home price for the year/zipcode
df_homes_2011['HomePrice'] = round(df_homes_2011.iloc[:,8: ].mean(axis=1), 2)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_homes_2011.head()
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     61639         0       10025        Zip        NY    NY  New York
# 1     84654         1       60657        Zip        IL    IL   Chicago
# 2     61637         2       10023        Zip        NY    NY  New York
# 3     91982         3       77494        Zip        TX    TX      Katy
# 4     84616         4       60614        Zip        IL    IL   Chicago
#
#                               Metro       CountyName  2011-01-31  ...  \
# 0       New York-Newark-Jersey City  New York County    780114.0  ...
# 1          Chicago-Naperville-Elgin      Cook County    406419.0  ...
# 2       New York-Newark-Jersey City  New York County    799250.0  ...
# 3  Houston-The Woodlands-Sugar Land    Harris County    268778.0  ...
# 4          Chicago-Naperville-Elgin      Cook County    514290.0  ...
#
#    2011-04-30  2011-05-31  2011-06-30  2011-07-31  2011-08-31  2011-09-30  \
# 0    785722.0    783425.0    782055.0    783642.0    784601.0    785216.0
# 1    402508.0    401686.0    399042.0    401282.0    399902.0    400388.0
# 2    819204.0    819243.0    820139.0    818610.0    821545.0    823646.0
# 3    265330.0    264122.0    263844.0    263843.0    263659.0    264226.0
# 4    508617.0    508506.0    505419.0    508759.0    507645.0    509103.0
#
#    2011-10-31  2011-11-30  2011-12-31  HomePrice
# 0    783347.0    784810.0    785198.0  784477.42
# 1    395881.0    396477.0    393375.0  400695.83
# 2    829552.0    834686.0    839187.0  821072.58
# 3    264723.0    265688.0    265795.0  265425.17
# 4    503178.0    503588.0    499874.0  507804.42
#
# [5 rows x 22 columns]

# %%
#drop monthly data
raw = df_homes_2011.iloc[:, 9:21]
df_homes_2011.drop(raw, axis=1, inplace=True)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_homes_2011.head()
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     61639         0       10025        Zip        NY    NY  New York
# 1     84654         1       60657        Zip        IL    IL   Chicago
# 2     61637         2       10023        Zip        NY    NY  New York
# 3     91982         3       77494        Zip        TX    TX      Katy
# 4     84616         4       60614        Zip        IL    IL   Chicago
#
#                               Metro       CountyName  HomePrice
# 0       New York-Newark-Jersey City  New York County  784477.42
# 1          Chicago-Naperville-Elgin      Cook County  400695.83
# 2       New York-Newark-Jersey City  New York County  821072.58
# 3  Houston-The Woodlands-Sugar Land    Harris County  265425.17
# 4          Chicago-Naperville-Elgin      Cook County  507804.42

# %%
#repeat for other DataFrames 2012-2018
#create new column for aver home price for the year/zipcode
df_homes_2012['HomePrice'] = round(df_homes_2012.iloc[:,8: ].mean(axis=1), 2)
df_homes_2013['HomePrice'] = round(df_homes_2013.iloc[:,8: ].mean(axis=1), 2)
df_homes_2014['HomePrice'] = round(df_homes_2014.iloc[:,8: ].mean(axis=1), 2)
df_homes_2015['HomePrice'] = round(df_homes_2015.iloc[:,8: ].mean(axis=1), 2)
df_homes_2016['HomePrice'] = round(df_homes_2016.iloc[:,8: ].mean(axis=1), 2)
df_homes_2017['HomePrice'] = round(df_homes_2017.iloc[:,8: ].mean(axis=1), 2)
df_homes_2018['HomePrice'] = round(df_homes_2018.iloc[:,8: ].mean(axis=1), 2)
df_homes_2019['HomePrice'] = round(df_homes_2019.iloc[:,8: ].mean(axis=1), 2)
df_homes_2020['HomePrice'] = round(df_homes_2020.iloc[:,8: ].mean(axis=1), 2)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
#drop monthly data from other DataFrames
DFs = [df_homes_2012, df_homes_2013, df_homes_2014, df_homes_2015, df_homes_2016, df_homes_2017, df_homes_2018, df_homes_2019]

for DF in DFs:
    #drop monthly data
    months = DF.iloc[:, 9:21]
    DF.drop(months, axis=1, inplace=True)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
drop = df_homes_2020.iloc[:, 9:18]
df_homes_2020.drop(drop, axis=1, inplace=True)

# %% [markdown]
# ### Data Joining

# %%
df_homes_2020.head()
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     61639         0       10025        Zip        NY    NY  New York
# 1     84654         1       60657        Zip        IL    IL   Chicago
# 2     61637         2       10023        Zip        NY    NY  New York
# 3     91982         3       77494        Zip        TX    TX      Katy
# 4     84616         4       60614        Zip        IL    IL   Chicago
#
#                               Metro       CountyName   HomePrice
# 0       New York-Newark-Jersey City  New York County   951924.67
# 1          Chicago-Naperville-Elgin      Cook County   490915.22
# 2       New York-Newark-Jersey City  New York County  1091064.33
# 3  Houston-The Woodlands-Sugar Land    Harris County   343916.44
# 4          Chicago-Naperville-Elgin      Cook County   634424.44

# %%
df_homes_2019
# Out:
#        RegionID  SizeRank  RegionName RegionType StateName State       City  \
# 0         61639         0       10025        Zip        NY    NY   New York
# 1         84654         1       60657        Zip        IL    IL    Chicago
# 2         61637         2       10023        Zip        NY    NY   New York
# 3         91982         3       77494        Zip        TX    TX       Katy
# 4         84616         4       60614        Zip        IL    IL    Chicago
# ...         ...       ...         ...        ...       ...   ...        ...
# 30362     76721     34430       43523        Zip        OH    OH    Malinta
# 30363     60758     34430        7703        Zip        NJ    NJ  Eatontown
# 30364     78801     34430       47865        Zip        IN    IN   Carlisle
# 30365     58117     35187         822        Zip        LA    LA  Choudrant
# 30366     58115     35187         820        Zip        LA    LA  Choudrant
#
#                                   Metro       CountyName   HomePrice
# 0           New York-Newark-Jersey City  New York County  1072056.17
# 1              Chicago-Naperville-Elgin      Cook County   490717.08
# 2           New York-Newark-Jersey City  New York County  1053399.33
# 3      Houston-The Woodlands-Sugar Land    Harris County   341633.50
# 4              Chicago-Naperville-Elgin      Cook County   639591.75
# ...                                 ...              ...         ...
# 30362                               NaN     Henry County    83879.67
# 30363       New York-Newark-Jersey City  Monmouth County   545483.92
# 30364                       Terre Haute  Sullivan County    41754.92
# 30365                            Ruston   Lincoln Parish   191554.75
# 30366                            Ruston   Lincoln Parish   238768.00
#
# [30367 rows x 10 columns]

# %%
#add Year column to each dataframe
df_homes_2011['Year'] = 2011
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_homes_2012['Year'] = 2012
df_homes_2013['Year'] = 2013
df_homes_2014['Year'] = 2014
df_homes_2015['Year'] = 2015
df_homes_2016['Year'] = 2016
df_homes_2017['Year'] = 2017
df_homes_2018['Year'] = 2018
df_homes_2019['Year'] = 2019
df_homes_2020['Year'] = 2020
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
df_homes_2019
# Out:
#        RegionID  SizeRank  RegionName RegionType StateName State       City  \
# 0         61639         0       10025        Zip        NY    NY   New York
# 1         84654         1       60657        Zip        IL    IL    Chicago
# 2         61637         2       10023        Zip        NY    NY   New York
# 3         91982         3       77494        Zip        TX    TX       Katy
# 4         84616         4       60614        Zip        IL    IL    Chicago
# ...         ...       ...         ...        ...       ...   ...        ...
# 30362     76721     34430       43523        Zip        OH    OH    Malinta
# 30363     60758     34430        7703        Zip        NJ    NJ  Eatontown
# 30364     78801     34430       47865        Zip        IN    IN   Carlisle
# 30365     58117     35187         822        Zip        LA    LA  Choudrant
# 30366     58115     35187         820        Zip        LA    LA  Choudrant
#
#                                   Metro       CountyName   HomePrice  Year
# 0           New York-Newark-Jersey City  New York County  1072056.17  2019
# 1              Chicago-Naperville-Elgin      Cook County   490717.08  2019
# 2           New York-Newark-Jersey City  New York County  1053399.33  2019
# 3      Houston-The Woodlands-Sugar Land    Harris County   341633.50  2019
# 4              Chicago-Naperville-Elgin      Cook County   639591.75  2019
# ...                                 ...              ...         ...   ...
# 30362                               NaN     Henry County    83879.67  2019
# 30363       New York-Newark-Jersey City  Monmouth County   545483.92  2019
# 30364                       Terre Haute  Sullivan County    41754.92  2019
# 30365                            Ruston   Lincoln Parish   191554.75  2019
# 30366                            Ruston   Lincoln Parish   238768.00  2019
#
# [30367 rows x 11 columns]

# %%
#concat each year's dataframe into a single dataframe
df_homes_2011_2012 = pd.concat([df_homes_2011, df_homes_2012])
df_homes_2011_2013 = pd.concat([df_homes_2011_2012, df_homes_2013])
df_homes_2011_2014 = pd.concat([df_homes_2011_2013, df_homes_2014])
df_homes_2011_2015 = pd.concat([df_homes_2011_2014, df_homes_2015])
df_homes_2011_2016 = pd.concat([df_homes_2011_2015, df_homes_2016])
df_homes_2011_2017 = pd.concat([df_homes_2011_2016, df_homes_2017])
df_homes_2011_2018 = pd.concat([df_homes_2011_2017, df_homes_2018])
df_homes_2011_2019 = pd.concat([df_homes_2011_2018, df_homes_2019])
df_homes_2011_2020 = pd.concat([df_homes_2011_2019, df_homes_2020], ignore_index=True)
df_homes_2011_2020
# Out:
#         RegionID  SizeRank  RegionName RegionType StateName State       City  \
# 0          61639         0       10025        Zip        NY    NY   New York
# 1          84654         1       60657        Zip        IL    IL    Chicago
# 2          61637         2       10023        Zip        NY    NY   New York
# 3          91982         3       77494        Zip        TX    TX       Katy
# 4          84616         4       60614        Zip        IL    IL    Chicago
# ...          ...       ...         ...        ...       ...   ...        ...
# 303665     76721     34430       43523        Zip        OH    OH    Malinta
# 303666     60758     34430        7703        Zip        NJ    NJ  Eatontown
# 303667     78801     34430       47865        Zip        IN    IN   Carlisle
# 303668     58117     35187         822        Zip        LA    LA  Choudrant
# 303669     58115     35187         820        Zip        LA    LA  Choudrant
#
#                                    Metro       CountyName  HomePrice  Year
# 0            New York-Newark-Jersey City  New York County  784477.42  2011
# 1               Chicago-Naperville-Elgin      Cook County  400695.83  2011
# 2            New York-Newark-Jersey City  New York County  821072.58  2011
# 3       Houston-The Woodlands-Sugar Land    Harris County  265425.17  2011
# 4               Chicago-Naperville-Elgin      Cook County  507804.42  2011
# ...                                  ...              ...        ...   ...
# 303665                               NaN     Henry County   84331.11  2020
# 303666       New York-Newark-Jersey City  Monmouth County  579932.56  2020
# 303667                       Terre Haute  Sullivan County   42896.56  2020
# 303668                            Ruston   Lincoln Parish  195888.67  2020
# 303669                            Ruston   Lincoln Parish  242009.56  2020
#
# [303670 rows x 11 columns]

# %%
df_homes_2011_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303670 entries, 0 to 303669
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   RegionID    303670 non-null  int64
#  1   SizeRank    303670 non-null  int64
#  2   RegionName  303670 non-null  int64
#  3   RegionType  303670 non-null  object
#  4   StateName   303670 non-null  object
#  5   State       303670 non-null  object
#  6   City        303670 non-null  object
#  7   Metro       232490 non-null  object
#  8   CountyName  303670 non-null  object
#  9   HomePrice   292604 non-null  float64
#  10  Year        303670 non-null  int64
# dtypes: float64(1), int64(4), object(6)
# memory usage: 25.5+ MB

# %%
df_homes_2011_2020.isna().sum()/len(df_homes_2011_2020)*100
# Out:
# RegionID       0.000000
# SizeRank       0.000000
# RegionName     0.000000
# RegionType     0.000000
# StateName      0.000000
# State          0.000000
# City           0.000000
# Metro         23.439918
# CountyName     0.000000
# HomePrice      3.644087
# Year           0.000000
# dtype: float64

# %%
df_homes_2011_2020.nunique()
# Out:
# RegionID       30367
# SizeRank       11070
# RegionName     30367
# RegionType         1
# StateName         51
# State             51
# City           14847
# Metro            861
# CountyName      1759
# HomePrice     282142
# Year              10
# dtype: int64

# %%
#dropped extraenous/duplicate columns
df_homes_2011_2020.drop(['RegionType', 'StateName', 'RegionID'], axis=1, inplace=True)

# %%
df_homes_2011_2020[df_homes_2011_2020.RegionName == 30906]
# Out:
#         SizeRank  RegionName State     City                    Metro  \
# 468          473       30906    GA  Augusta  Augusta-Richmond County
# 30835        473       30906    GA  Augusta  Augusta-Richmond County
# 61202        473       30906    GA  Augusta  Augusta-Richmond County
# 91569        473       30906    GA  Augusta  Augusta-Richmond County
# 121936       473       30906    GA  Augusta  Augusta-Richmond County
# 152303       473       30906    GA  Augusta  Augusta-Richmond County
# 182670       473       30906    GA  Augusta  Augusta-Richmond County
# 213037       473       30906    GA  Augusta  Augusta-Richmond County
# 243404       473       30906    GA  Augusta  Augusta-Richmond County
# 273771       473       30906    GA  Augusta  Augusta-Richmond County
#
#              CountyName  HomePrice  Year
# 468     Richmond County        NaN  2011
# 30835   Richmond County        NaN  2012
# 61202   Richmond County        NaN  2013
# 91569   Richmond County        NaN  2014
# 121936  Richmond County        NaN  2015
# 152303  Richmond County        NaN  2016
# 182670  Richmond County   63458.00  2017
# 213037  Richmond County   71968.42  2018
# 243404  Richmond County   79020.33  2019
# 273771  Richmond County   84938.22  2020

# %% [markdown]
# ### Save Data

# %%
df_homes_2011_2020.to_csv(r'/Users/josephfrasca/Coding_Stuff/Springboard/Capstone_2/data/interim/df_homePrices_2011_2020.csv', index=False)

# %% [markdown]
# ### Notes

# %%
#change RegionName to Zipcode
#replace NaNs with medians? (or drop the rows for ML) - see mentor notes to help decide strategy
#figure out metro NaNs??

# %% [markdown]
# ### Summary

# %% [markdown]
# - loaded home price data by zipcode from zillow public data
#
# CLEANING
# - inspected data and isolated annual data into separate DataFrames from 2011-2020
# - looked at NaNs
# - created new column for average home price for the year by zipcode and dropped the by month data
# - added a Year column to each dataframe
#
# JOINING
# - concat-ed each year's dataframe into a single dataframe
# - inspected for NaNs, much less now (3.6% of home prices)
# - dropped extraenous/duplicate columns
# - saved new dataframe
